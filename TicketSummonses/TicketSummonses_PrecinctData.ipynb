# %%
import os
import pandas as pd

# %% [markdown]
# ## 2011 Data

# %%
path = '/Users/JordanVani/Documents/NYU/ADS/Report/Vision_Zero/TicketSummonses/Data/2011_12_sum_excel/'
f2011 = os.listdir(path)

# %%
Tickets2011 = {}
for x in f2011[1:-1]:
    Tickets2011['Precinct' + x[0:3]] = pd.read_excel(path + x, parse_cols = [0, 2])
    Tickets2011['Precinct' + x[0:3]].columns = ['MovingViolations', 'P'  + '2011_' + x[0:3]]
#    Tickets2011['Precinct' + x[0:3]].drop(Tickets2011['Precinct' + x[0:3]].index[[0, 1, 2, 3, 36, 37, 38]], 
#                                          inplace = True)
df2011 = pd.concat(Tickets2011, axis = 1)
df2011.columns = df2011.columns.droplevel()
df2011 = df2011.T.drop_duplicates().T

# %%
df2011.shape
# Out:
# (39, 152)

# %%
df2011.head()
# Out:
#                         MovingViolations P2011_001  \
# 0                           1st Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN         8
# 4     Brake Lights (Defect.or  Improper)       514
#
#                         MovingViolations P2011_005  \
# 0                           5th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN        10
# 4     Brake Lights (Defect.or  Improper)        83
#
#                         MovingViolations P2011_006  \
# 0                           6th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN        19
# 4     Brake Lights (Defect.or  Improper)       105
#
#                         MovingViolations P2011_007  \
# 0                           7th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN         7
# 4     Brake Lights (Defect.or  Improper)         0
#
#                         MovingViolations P2011_009    ...     \
# 0                           9th Precinct       NaN    ...
# 1                               December       NaN    ...
# 2  Offense Description\nBacking Unsafely  YTD 2011    ...
# 3                                    NaN         4    ...
# 4     Brake Lights (Defect.or  Improper)       311    ...
#
#                         MovingViolations P2011_114  \
# 0                         114th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN        15
# 4     Brake Lights (Defect.or  Improper)         0
#
#                         MovingViolations P2011_115  \
# 0                         115th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN        25
# 4     Brake Lights (Defect.or  Improper)        32
#
#                         MovingViolations P2011_120  \
# 0                         120th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN        17
# 4     Brake Lights (Defect.or  Improper)      1108
#
#                         MovingViolations P2011_122  \
# 0                         122nd Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN         7
# 4     Brake Lights (Defect.or  Improper)      1371
#
#                         MovingViolations P2011_123
# 0                         123rd Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2011
# 3                                    NaN         3
# 4     Brake Lights (Defect.or  Improper)       338
#
# [5 rows x 152 columns]

# %% [markdown]
# ## 2012 Data

# %%
path = '/Users/JordanVani/Documents/NYU/ADS/Report/Vision_Zero/TicketSummonses/Data/2012_12_sum_excel/'
f2012 = os.listdir(path)

# %%
Tickets2012 = {}
for x in f2012[1:-1]:
    Tickets2012['Precinct' + x[0:3]] = pd.read_excel(path + x, parse_cols = [0, 2])
    Tickets2012['Precinct' + x[0:3]].columns = ['MovingViolations', 'P'  + '2012_' + x[0:3]]
#    Tickets2012['Precinct' + x[0:3]].drop(Tickets2012['Precinct' + x[0:3]].index[[0, 1, 2, 3, 36, 37, 38]], 
#                                          inplace = True)
df2012 = pd.concat(Tickets2012, axis = 1)
df2012.columns = df2012.columns.droplevel()
df2012 = df2012.T.drop_duplicates().T

# %%
df2012.shape
# Out:
# (39, 152)

# %%
df2012.head()
# Out:
#                         MovingViolations P2012_001  \
# 0                           1st Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN         8
# 4     Brake Lights (Defect.or  Improper)       618
#
#                         MovingViolations P2012_005  \
# 0                           5th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN         8
# 4     Brake Lights (Defect.or  Improper)        96
#
#                         MovingViolations P2012_006  \
# 0                           6th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN        16
# 4     Brake Lights (Defect.or  Improper)       119
#
#                         MovingViolations P2012_007  \
# 0                           7th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN         3
# 4     Brake Lights (Defect.or  Improper)         0
#
#                         MovingViolations P2012_009    ...     \
# 0                           9th Precinct       NaN    ...
# 1                               December       NaN    ...
# 2  Offense Description\nBacking Unsafely  YTD 2012    ...
# 3                                    NaN        19    ...
# 4     Brake Lights (Defect.or  Improper)        58    ...
#
#                         MovingViolations P2012_114  \
# 0                         114th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN        25
# 4     Brake Lights (Defect.or  Improper)         0
#
#                         MovingViolations P2012_115  \
# 0                         115th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN        24
# 4     Brake Lights (Defect.or  Improper)       207
#
#                         MovingViolations P2012_120  \
# 0                         120th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN        31
# 4     Brake Lights (Defect.or  Improper)      1119
#
#                         MovingViolations P2012_122  \
# 0                         122nd Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN         8
# 4     Brake Lights (Defect.or  Improper)       939
#
#                         MovingViolations P2012_123
# 0                         123rd Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2012
# 3                                    NaN         7
# 4     Brake Lights (Defect.or  Improper)       511
#
# [5 rows x 152 columns]

# %% [markdown]
# ## 2013 Data

# %%
path = '/Users/JordanVani/Documents/NYU/ADS/Report/Vision_Zero/TicketSummonses/Data/2013_12_sum_excel/'
f2013 = os.listdir(path)

# %%
Tickets2013 = {}
for x in f2013[1:-1]:
    Tickets2013['Precinct' + x[0:3]] = pd.read_excel(path + x, parse_cols = [0, 2])
    Tickets2013['Precinct' + x[0:3]].columns = ['MovingViolations', 'P'  + '2013_' + x[0:3]]
#    Tickets2013['Precinct' + x[0:3]].drop(Tickets2013['Precinct' + x[0:3]].index[[0, 1, 2, 3, 36, 37, 38]], 
#                                          inplace = True)
df2013 = pd.concat(Tickets2013, axis = 1)
df2013.columns = df2013.columns.droplevel()
df2013 = df2013.T.drop_duplicates().T

# %%
df2013.shape
# Out:
# (42, 154)

# %%
df2013.head()
# Out:
#                         MovingViolations P2013_001  \
# 0                           1st Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN         6
# 4     Brake Lights (Defect.or  Improper)       536
#
#                         MovingViolations P2013_005  \
# 0                           5th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN        12
# 4     Brake Lights (Defect.or  Improper)       326
#
#                         MovingViolations P2013_006  \
# 0                           6th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN        20
# 4     Brake Lights (Defect.or  Improper)       126
#
#                         MovingViolations P2013_007  \
# 0                           7th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN         4
# 4     Brake Lights (Defect.or  Improper)         0
#
#                         MovingViolations P2013_009    ...     \
# 0                           9th Precinct       NaN    ...
# 1                               December       NaN    ...
# 2  Offense Description\nBacking Unsafely  YTD 2013    ...
# 3                                    NaN        11    ...
# 4     Brake Lights (Defect.or  Improper)        85    ...
#
#                         MovingViolations P2013_115  \
# 0                         115th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN        33
# 4     Brake Lights (Defect.or  Improper)         3
#
#                         MovingViolations P2013_120  \
# 0                         120th Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN        17
# 4     Brake Lights (Defect.or  Improper)      1241
#
#                         MovingViolations P2013_121  \
# 0                         121st Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN        11
# 4     Brake Lights (Defect.or  Improper)       410
#
#                         MovingViolations P2013_122  \
# 0                         122nd Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN        10
# 4     Brake Lights (Defect.or  Improper)       441
#
#                         MovingViolations P2013_123
# 0                         123rd Precinct       NaN
# 1                               December       NaN
# 2  Offense Description\nBacking Unsafely  YTD 2013
# 3                                    NaN         4
# 4     Brake Lights (Defect.or  Improper)       629
#
# [5 rows x 154 columns]

# %% [markdown]
# ## 2014 Data

# %%
path = '/Users/JordanVani/Documents/NYU/ADS/Report/Vision_Zero/TicketSummonses/Data/2014_12_sum_excel/'
f2014 = os.listdir(path)

# %%
Tickets2014 = {}
for x in f2014[1:-1]:
    Tickets2014['Precinct' + x[0:3]] = pd.read_excel(path + x, parse_cols = [0, 2])
    Tickets2014['Precinct' + x[0:3]].columns = ['MovingViolations', 'P'  + '2014_' + x[0:3]]
#    Tickets2014['Precinct' + x[0:3]].drop(Tickets2014['Precinct' + x[0:3]].index[[0, 1, 2, 3, 36, 37, 38]], 
#                                          inplace = True)
df2014 = pd.concat(Tickets2014, axis = 1)
df2014.columns = df2014.columns.droplevel()
df2014 = df2014.T.drop_duplicates().T

# %%
df2014.shape
# Out:
# (40, 154)

# %%
df2014.head()
# Out:
#       MovingViolations   P2014_001     MovingViolations   P2014_005  \
# 0         1st Precinct         NaN         5th Precinct         NaN
# 1            December          NaN            December          NaN
# 2               001sum         NaN               005sum         NaN
# 3  Offense Description  YTD   2014  Offense Description  YTD   2014
# 4     Backing Unsafely          15     Backing Unsafely           8
#
#       MovingViolations   P2014_006     MovingViolations   P2014_007  \
# 0         6th Precinct         NaN         7th Precinct         NaN
# 1            December          NaN            December          NaN
# 2               006sum         NaN               007sum         NaN
# 3  Offense Description  YTD   2014  Offense Description  YTD   2014
# 4     Backing Unsafely          17     Backing Unsafely           5
#
#       MovingViolations   P2014_009     ...         MovingViolations  \
# 0         9th Precinct         NaN     ...           115th Precinct
# 1            December          NaN     ...                December
# 2               009sum         NaN     ...                   115sum
# 3  Offense Description  YTD   2014     ...      Offense Description
# 4     Backing Unsafely          12     ...         Backing Unsafely
#
#     P2014_115     MovingViolations   P2014_120     MovingViolations  \
# 0         NaN       120th Precinct         NaN       121st Precinct
# 1         NaN            December          NaN            December
# 2         NaN               120sum         NaN               121sum
# 3  YTD   2014  Offense Description  YTD   2014  Offense Description
# 4          37     Backing Unsafely          17     Backing Unsafely
#
#     P2014_121     MovingViolations   P2014_122     MovingViolations  \
# 0         NaN       122nd Precinct         NaN       123rd Precinct
# 1         NaN            December          NaN            December
# 2         NaN               122sum         NaN               123sum
# 3  YTD   2014  Offense Description  YTD   2014  Offense Description
# 4          15     Backing Unsafely          11     Backing Unsafely
#
#     P2014_123
# 0         NaN
# 1         NaN
# 2         NaN
# 3  YTD   2014
# 4           8
#
# [5 rows x 154 columns]

# %% [markdown]
# ## 2015 Data

# %%
path = '/Users/JordanVani/Documents/NYU/ADS/Report/Vision_Zero/TicketSummonses/Data/2015_12_sum_excel/'
f2015 = os.listdir(path)

# %%
Tickets2015 = {}
for x in f2015[2:]:
    Tickets2015['Precinct' + x[9:12]] = pd.read_excel(path + x, parse_cols = [0, 2])
    Tickets2015['Precinct' + x[9:12]].columns = ['MovingViolations', 'P'  + '2015_' + x[0:3]]
#    Tickets2015['Precinct' + x[9:12]].drop(Tickets2015['Precinct' + x[0:3]].index[[0, 1, 2, 3, 36, 37, 38]], 
#                                          inplace = True)
df2015 = pd.concat(Tickets2015, axis = 1)
df2015.columns = df2015.columns.droplevel()
df2015 = df2015.T.drop_duplicates().T

# %%
df2015.shape
# Out:
# (41, 154)

# %%
df2015.head()
# Out:
#       MovingViolations P2013_mv-     MovingViolations P2013_mv-  \
# 0         1st Precinct       NaN         5th Precinct       NaN
# 1             December       NaN             December       NaN
# 2               001sum       NaN               005sum       NaN
# 3  Offense Description  YTD 2015  Offense Description  YTD 2015
# 4     Backing Unsafely         6     Backing Unsafely         8
#
#       MovingViolations P2013_mv-     MovingViolations P2013_mv-  \
# 0         6th Precinct       NaN         7th Precinct       NaN
# 1             December       NaN             December       NaN
# 2               006sum       NaN               007sum       NaN
# 3  Offense Description  YTD 2015  Offense Description  YTD 2015
# 4     Backing Unsafely        24     Backing Unsafely         5
#
#       MovingViolations P2013_mv-    ...        MovingViolations P2013_mv-  \
# 0         9th Precinct       NaN    ...          115th Precinct       NaN
# 1             December       NaN    ...                December       NaN
# 2               009sum       NaN    ...                  115sum       NaN
# 3  Offense Description  YTD 2015    ...     Offense Description  YTD 2015
# 4     Backing Unsafely         0    ...        Backing Unsafely        14
#
#       MovingViolations P2013_mv-     MovingViolations P2013_mv-  \
# 0       120th Precinct       NaN       121st Precinct       NaN
# 1             December       NaN             December       NaN
# 2               120sum       NaN               121sum       NaN
# 3  Offense Description  YTD 2015  Offense Description  YTD 2015
# 4     Backing Unsafely         9     Backing Unsafely        15
#
#       MovingViolations P2013_mv-     MovingViolations P2013_mv-
# 0       122nd Precinct       NaN       123rd Precinct       NaN
# 1             December       NaN             December       NaN
# 2               122sum       NaN               123sum       NaN
# 3  Offense Description  YTD 2015  Offense Description  YTD 2015
# 4     Backing Unsafely         9     Backing Unsafely         9
#
# [5 rows x 154 columns]
